# %%
import os
import pickle
import warnings
import numpy as np
import pandas as pd
import shap
import matplotlib.pyplot as plt

from itertools import product
from sklearn.model_selection import train_test_split, KFold
from lifelines.statistics import logrank_test
from lifelines import CoxPHFitter
from sksurv.linear_model import CoxnetSurvivalAnalysis

import optuna

warnings.filterwarnings("ignore")
random_state = 42

results_tracker = {}

# -----------------------------------------------------------------------------
# Data Loading & Preprocessing
# -----------------------------------------------------------------------------
def load_data(base_path):
    file_paths = {
        "clinical_data": os.path.join(base_path, "2019_TCGA-CDR-SupplementalTableS1.xlsx"),
        "new_labels": os.path.join(base_path, "Matrix_WHO2021.csv"),
        "gbm_data": os.path.join(base_path, "GBM_450K_Filtered_X-Y,SNPs,Non-overlap850K.csv"),
        "lgg_data": os.path.join(base_path, "LGG-450K_Filtered_X-Y,SNPs,Non-overlap850K.csv"),
    }
    for key, path in file_paths.items():
        if not os.path.exists(path):
            print(f"❌ Error: Missing {key} file: {path}")
            return None

    print("📂 Loading data...")
    main_data_df = pd.read_excel(file_paths["clinical_data"])
    new_categories = pd.read_csv(file_paths["new_labels"])
    gbm_data = pd.read_csv(file_paths["gbm_data"])
    lgg_data = pd.read_csv(file_paths["lgg_data"])
    print("✅ Data Loaded Successfully!")

    results_tracker["data_load"] = {
        "clinical_data": main_data_df.shape,
        "new_labels": new_categories.shape,
        "gbm_data": gbm_data.shape,
        "lgg_data": lgg_data.shape
    }
    return main_data_df, new_categories, gbm_data, lgg_data

def preprocess_methylation_data(df):
    df_trns = df.T
    df_trns.columns = df_trns.iloc[0]
    return df_trns[1:]

def merge_data(main_data_df, new_categories, gbm_data, lgg_data):
    main_data_df.rename(columns={'bcr_patient_barcode': 'Patient_ID'}, inplace=True)
    filtered_data_df = main_data_df[main_data_df['type'].isin(['GBM', 'LGG'])]
    merged_clinical_data = pd.merge(filtered_data_df, new_categories, on='Patient_ID', how='inner')

    gbm_trns_final = preprocess_methylation_data(gbm_data)
    lgg_trns_final = preprocess_methylation_data(lgg_data)
    merged_methylation_data = pd.concat([gbm_trns_final, lgg_trns_final])
    merged_methylation_data.rename(columns={'Index': 'Patient_ID'}, inplace=True)

    final_data = pd.merge(
        merged_methylation_data,
        merged_clinical_data,
        left_index=True,
        right_on='Patient_ID',
        how='inner'
    )
    print(f"✅ Final Merged Data Shape: {final_data.shape}")
    results_tracker["merged_data"] = final_data.shape
    return final_data

def split_data(df):
    df = df[df['classification.2021_simplified.labels'] != 'unclassified']
    subsets = {
        'astrocytoma': df[df['classification.2021_simplified.labels'] == 'astrocytoma'],
        'glioblastoma': df[df['classification.2021_simplified.labels'] == 'glioblastoma'],
        'oligodendroglioma': df[df['classification.2021_simplified.labels'] == 'oligodendroglioma']
    }
    print(f"✅ Data Split into: {', '.join(subsets.keys())}")
    results_tracker["split_data"] = {k: v.shape for k, v in subsets.items()}
    return subsets

def prepare_subtype_data(df):
    df = df.dropna(subset=["OS.time", "OS"])
    df = df.apply(pd.to_numeric, errors="coerce")
    df["OS"] = df["OS"].astype(int)

    methylation_features = [col for col in df.columns if col.startswith("cg")]
    if len(methylation_features) == 0:
        print("❌ No valid methylation features found. Skipping.")
        return None

    X = df[methylation_features]
    y = df[['OS.time', 'OS']]

    X_train_val, X_test, y_train_val, y_test = train_test_split(
        X, y, test_size=0.2, random_state=random_state
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_val, y_train_val, test_size=0.25, random_state=random_state
    )
    
    print(f"✅ Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return {
        "X_train": X_train,
        "X_val": X_val,
        "X_test": X_test,
        "y_train": y_train,
        "y_val": y_val,
        "y_test": y_test
    }

def convert_survival_data(y_df):
    return np.array(
        [(bool(event), time) for event, time in zip(y_df["OS"], y_df["OS.time"])],
        dtype=[('event', '?'), ('time', '<f8')]
    )

# -----------------------------------------------------------------------------
# Training & Evaluation
# -----------------------------------------------------------------------------
def train_lasso_cox_model(X_train, y_train_struct, alpha_min_ratio=0.5, n_alphas=50):
    model = CoxnetSurvivalAnalysis(
        l1_ratio=1.0, alpha_min_ratio=alpha_min_ratio, n_alphas=n_alphas
    )
    model.fit(X_train, y_train_struct)
    return model

def extract_significant_features(coxnet, X_train):
    best_alpha_index = np.argmax(np.sum(coxnet.coef_ != 0, axis=0))
    selected_features = X_train.columns[coxnet.coef_[:, best_alpha_index] != 0]
    return selected_features

def evaluate_model(coxnet, X_train, y_train_struct, X_test, y_test_struct):
    train_c_index = coxnet.score(X_train, y_train_struct)
    test_c_index = coxnet.score(X_test, y_test_struct)
    return train_c_index, test_c_index

# -----------------------------------------------------------------------------
# Optuna-based CV Tuning
# -----------------------------------------------------------------------------
from sklearn.model_selection import KFold
import optuna

def cross_val_c_index(X, y_struct, alpha_min_ratio, n_alphas, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    c_indexes = []
    for train_idx, val_idx in kf.split(X):
        X_train_fold = X.iloc[train_idx]
        X_val_fold   = X.iloc[val_idx]
        y_train_fold = y_struct[train_idx]
        y_val_fold   = y_struct[val_idx]

        model = CoxnetSurvivalAnalysis(
            l1_ratio=1.0, alpha_min_ratio=alpha_min_ratio, n_alphas=n_alphas
        )
        model.fit(X_train_fold, y_train_fold)
        c_indexes.append(model.score(X_val_fold, y_val_fold))

    return np.mean(c_indexes)

def tune_hyperparameters_optuna(X, y_struct, n_trials=20):
    def objective(trial):
        alpha_min_ratio = trial.suggest_float("alpha_min_ratio", 0.1, 0.9)
        n_alphas = trial.suggest_int("n_alphas", 10, 100)
        return cross_val_c_index(X, y_struct, alpha_min_ratio, n_alphas, n_splits=5)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=n_trials)
    return study.best_params

# -----------------------------------------------------------------------------
# SHAP Explanation
# -----------------------------------------------------------------------------
def compute_shap_importance(model, X_subset):
    """
    Permutation Explainer requires at least 2*num_features + 1 evals.
    So only call this AFTER reducing features significantly (retrain on subset).
    """
    print(f"🔍 Computing SHAP on {X_subset.shape[1]} features...")
    explainer = shap.Explainer(model.predict, X_subset)
    shap_values = explainer(X_subset)
    shap.summary_plot(shap_values, X_subset, show=False)
    plt.title("SHAP Summary Plot")
    plt.show()

# -----------------------------------------------------------------------------
# Main Workflow
# -----------------------------------------------------------------------------
def main():
    base_path = "/Users/nijat/Downloads/OneDrive_1_2024-09-21/Data"
    data_loaded = load_data(base_path)
    if data_loaded is None:
        return

    main_data_df, new_categories, gbm_data, lgg_data = data_loaded
    merged_data = merge_data(main_data_df, new_categories, gbm_data, lgg_data)
    subsets = split_data(merged_data)

    split_data_dict = {}
    for label, df in subsets.items():
        print(f"\n🔹 Processing subtype={label}")
        subtype_data = prepare_subtype_data(df)
        if subtype_data is None:
            continue
        # Convert survival data
        subtype_data["y_train_struct"] = convert_survival_data(subtype_data["y_train"])
        subtype_data["y_val_struct"]   = convert_survival_data(subtype_data["y_val"])
        subtype_data["y_test_struct"]  = convert_survival_data(subtype_data["y_test"])
        split_data_dict[label] = subtype_data

    for label, data in split_data_dict.items():
        print(f"\n==============================")
        print(f"🔹 Subtype: {label}")

        # 1) Baseline
        X_train = data["X_train"]
        X_val   = data["X_val"]
        X_test  = data["X_test"]

        y_train_struct = data["y_train_struct"]
        y_val_struct   = data["y_val_struct"]
        y_test_struct  = data["y_test_struct"]

        print("🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50")
        baseline_model = train_lasso_cox_model(X_train, y_train_struct,
                                               alpha_min_ratio=0.5, n_alphas=50)
        train_c, test_c = evaluate_model(baseline_model, X_train, y_train_struct,
                                         X_test, y_test_struct)
        print(f"   Baseline C-index -> Train={train_c:.3f}, Test={test_c:.3f}")

        # 2) Hyperparam Tuning with Optuna
        print("🔸 Tuning with Optuna + 5-fold CV...")
        best_params = tune_hyperparameters_optuna(X_train, y_train_struct, n_trials=20)
        print(f"   Best params -> {best_params}")

        # 3) Final Model on Train+Val
        X_train_val = pd.concat([X_train, X_val])
        y_train_val = pd.concat([data["y_train"], data["y_val"]])
        y_train_val_struct = convert_survival_data(y_train_val)

        final_model = train_lasso_cox_model(X_train_val, y_train_val_struct,
                                            alpha_min_ratio=best_params["alpha_min_ratio"],
                                            n_alphas=best_params["n_alphas"])
        # Evaluate
        final_train_c, final_test_c = evaluate_model(
            final_model, X_train_val, y_train_val_struct,
            X_test, y_test_struct
        )
        print(f"   Final Model -> Train+Val C-index={final_train_c:.3f}, Test C-index={final_test_c:.3f}")

        # 4) Extract subset
        selected_features = extract_significant_features(final_model, X_train_val)
        print(f"   -> {len(selected_features)} features retained")

        # 5) Retrain only on the subset (to reduce feature count for SHAP)
        final_model_subset = train_lasso_cox_model(
            X_train_val[selected_features],
            y_train_val_struct,
            alpha_min_ratio=best_params["alpha_min_ratio"],
            n_alphas=best_params["n_alphas"]
        )
        # Evaluate subset model
        subset_train_c, subset_test_c = evaluate_model(
            final_model_subset,
            X_train_val[selected_features],
            y_train_val_struct,
            X_test[selected_features],
            y_test_struct
        )
        print(f"   Subset Model -> Train+Val C-index={subset_train_c:.3f}, Test C-index={subset_test_c:.3f}")

        # 6) SHAP Explanation on final subset model
        #    With fewer features, we avoid massive permutations
        compute_shap_importance(final_model_subset, X_train_val[selected_features])

    print("\n✅ Workflow Complete!")

if __name__ == "__main__":
    main()
# Out:
# 📂 Loading data...
# ✅ Data Loaded Successfully!
# ✅ Final Merged Data Shape: (653, 403991)
# ✅ Data Split into: astrocytoma, glioblastoma, oligodendroglioma
#
# 🔹 Processing subtype=astrocytoma
# ✅ Train: 153, Val: 51, Test: 52
#
# 🔹 Processing subtype=glioblastoma
# ✅ Train: 116, Val: 39, Test: 39
#
# 🔹 Processing subtype=oligodendroglioma
# ✅ Train: 100, Val: 34, Test: 34
#
# ==============================
# 🔹 Subtype: astrocytoma
# 🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50
# [I 2025-03-03 16:58:23,748] A new study created in memory with name: no-name-60adfda1-0523-4a82-965f-e2c16de06c94
#    Baseline C-index -> Train=0.851, Test=0.673
# 🔸 Tuning with Optuna + 5-fold CV...
# [I 2025-03-03 16:58:38,399] Trial 0 finished with value: 0.7103214550166606 and parameters: {'alpha_min_ratio': 0.4727351501882703, 'n_alphas': 79}. Best is trial 0 with value: 0.7103214550166606.
# [I 2025-03-03 16:58:52,960] Trial 1 finished with value: 0.7603476930942683 and parameters: {'alpha_min_ratio': 0.7567161943470951, 'n_alphas': 79}. Best is trial 1 with value: 0.7603476930942683.
# [I 2025-03-03 16:59:08,575] Trial 2 finished with value: 0.7467549188131379 and parameters: {'alpha_min_ratio': 0.6062789913736767, 'n_alphas': 93}. Best is trial 1 with value: 0.7603476930942683.
# [I 2025-03-03 16:59:18,668] Trial 3 finished with value: 0.718598182331059 and parameters: {'alpha_min_ratio': 0.19663602870280333, 'n_alphas': 19}. Best is trial 1 with value: 0.7603476930942683.
# [I 2025-03-03 16:59:28,889] Trial 4 finished with value: 0.7528682410394738 and parameters: {'alpha_min_ratio': 0.8342414521157305, 'n_alphas': 25}. Best is trial 1 with value: 0.7603476930942683.
# [I 2025-03-03 16:59:39,903] Trial 5 finished with value: 0.7705266083108548 and parameters: {'alpha_min_ratio': 0.6493993284323092, 'n_alphas': 36}. Best is trial 5 with value: 0.7705266083108548.
# [I 2025-03-03 16:59:50,287] Trial 6 finished with value: 0.7205502635708114 and parameters: {'alpha_min_ratio': 0.5174242926480074, 'n_alphas': 26}. Best is trial 5 with value: 0.7705266083108548.
# [I 2025-03-03 17:00:05,614] Trial 7 finished with value: 0.6984975626311243 and parameters: {'alpha_min_ratio': 0.1384033239279675, 'n_alphas': 76}. Best is trial 5 with value: 0.7705266083108548.
# [I 2025-03-03 17:00:19,252] Trial 8 finished with value: 0.7541285150120766 and parameters: {'alpha_min_ratio': 0.8153704894533069, 'n_alphas': 68}. Best is trial 5 with value: 0.7705266083108548.
# [I 2025-03-03 17:00:31,193] Trial 9 finished with value: 0.7560976930942684 and parameters: {'alpha_min_ratio': 0.7920117384940433, 'n_alphas': 46}. Best is trial 5 with value: 0.7705266083108548.
# [I 2025-03-03 17:00:43,314] Trial 10 finished with value: 0.7087674670756863 and parameters: {'alpha_min_ratio': 0.3293913960142557, 'n_alphas': 45}. Best is trial 5 with value: 0.7705266083108548.
# [I 2025-03-03 17:00:56,407] Trial 11 finished with value: 0.7719320137162604 and parameters: {'alpha_min_ratio': 0.6661679546528578, 'n_alphas': 57}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:01:09,177] Trial 12 finished with value: 0.7705266083108548 and parameters: {'alpha_min_ratio': 0.6496644139849613, 'n_alphas': 53}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:01:20,186] Trial 13 finished with value: 0.7685266083108548 and parameters: {'alpha_min_ratio': 0.6609344282450236, 'n_alphas': 35}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:01:33,939] Trial 14 finished with value: 0.7121309788261843 and parameters: {'alpha_min_ratio': 0.4507940836524078, 'n_alphas': 65}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:01:44,920] Trial 15 finished with value: 0.7447231096066713 and parameters: {'alpha_min_ratio': 0.8907250239450445, 'n_alphas': 35}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:01:58,078] Trial 16 finished with value: 0.7556820137162603 and parameters: {'alpha_min_ratio': 0.7083976145404536, 'n_alphas': 60}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:02:07,501] Trial 17 finished with value: 0.7434946448405353 and parameters: {'alpha_min_ratio': 0.5625499458380593, 'n_alphas': 14}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:02:19,039] Trial 18 finished with value: 0.714231752789972 and parameters: {'alpha_min_ratio': 0.385015176071445, 'n_alphas': 39}. Best is trial 11 with value: 0.7719320137162604.
# [I 2025-03-03 17:02:31,561] Trial 19 finished with value: 0.7556820137162603 and parameters: {'alpha_min_ratio': 0.7071842720203563, 'n_alphas': 51}. Best is trial 11 with value: 0.7719320137162604.
#    Best params -> {'alpha_min_ratio': 0.6661679546528578, 'n_alphas': 57}
#    Final Model -> Train+Val C-index=0.803, Test C-index=0.715
#    -> 6 features retained
#    Subset Model -> Train+Val C-index=0.803, Test C-index=0.715
# 🔍 Computing SHAP on 6 features...
# ==============================
# 🔹 Subtype: glioblastoma
# 🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50
# [I 2025-03-03 17:02:42,434] A new study created in memory with name: no-name-0f5ffce7-469f-49a6-90d5-bb9150aaa66b
#    Baseline C-index -> Train=0.844, Test=0.566
# 🔸 Tuning with Optuna + 5-fold CV...
# [I 2025-03-03 17:02:51,477] Trial 0 finished with value: 0.5095679500216235 and parameters: {'alpha_min_ratio': 0.7428272999443101, 'n_alphas': 17}. Best is trial 0 with value: 0.5095679500216235.
# [I 2025-03-03 17:03:01,776] Trial 1 finished with value: 0.5027980301287521 and parameters: {'alpha_min_ratio': 0.6930397622724789, 'n_alphas': 38}. Best is trial 0 with value: 0.5095679500216235.
# [I 2025-03-03 17:03:14,952] Trial 2 finished with value: 0.5066387278863339 and parameters: {'alpha_min_ratio': 0.22716497061832464, 'n_alphas': 67}. Best is trial 0 with value: 0.5095679500216235.
# [I 2025-03-03 17:03:28,718] Trial 3 finished with value: 0.5185443962024965 and parameters: {'alpha_min_ratio': 0.6371562713499687, 'n_alphas': 92}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:03:39,264] Trial 4 finished with value: 0.5171330019544371 and parameters: {'alpha_min_ratio': 0.13176964830559365, 'n_alphas': 28}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:03:51,969] Trial 5 finished with value: 0.5101860937357152 and parameters: {'alpha_min_ratio': 0.23510411252569627, 'n_alphas': 63}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:04:01,685] Trial 6 finished with value: 0.49338582317938406 and parameters: {'alpha_min_ratio': 0.45043230888706, 'n_alphas': 26}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:04:10,156] Trial 7 finished with value: 0.5083843545509483 and parameters: {'alpha_min_ratio': 0.7621988720923837, 'n_alphas': 10}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:04:23,401] Trial 8 finished with value: 0.5161038659275025 and parameters: {'alpha_min_ratio': 0.6268885867255731, 'n_alphas': 86}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:04:36,193] Trial 9 finished with value: 0.5076553130608261 and parameters: {'alpha_min_ratio': 0.40010426663422116, 'n_alphas': 73}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:04:46,524] Trial 10 finished with value: 0.4916023437277275 and parameters: {'alpha_min_ratio': 0.8943170105926328, 'n_alphas': 94}. Best is trial 3 with value: 0.5185443962024965.
# [I 2025-03-03 17:04:58,746] Trial 11 finished with value: 0.5247191185829896 and parameters: {'alpha_min_ratio': 0.1177873029227343, 'n_alphas': 45}. Best is trial 11 with value: 0.5247191185829896.
# [I 2025-03-03 17:05:09,673] Trial 12 finished with value: 0.49382431740826965 and parameters: {'alpha_min_ratio': 0.5587522982653463, 'n_alphas': 46}. Best is trial 11 with value: 0.5247191185829896.
# [I 2025-03-03 17:05:21,270] Trial 13 finished with value: 0.5096912686787232 and parameters: {'alpha_min_ratio': 0.34256474169426265, 'n_alphas': 51}. Best is trial 11 with value: 0.5247191185829896.
# [I 2025-03-03 17:05:36,274] Trial 14 finished with value: 0.5209033379069192 and parameters: {'alpha_min_ratio': 0.10769265097275027, 'n_alphas': 80}. Best is trial 11 with value: 0.5247191185829896.
# [I 2025-03-03 17:05:50,616] Trial 15 finished with value: 0.5207219235042876 and parameters: {'alpha_min_ratio': 0.1379651500943193, 'n_alphas': 76}. Best is trial 11 with value: 0.5247191185829896.
# [I 2025-03-03 17:06:04,585] Trial 16 finished with value: 0.5142897944664998 and parameters: {'alpha_min_ratio': 0.26646194713936644, 'n_alphas': 82}. Best is trial 11 with value: 0.5247191185829896.
# [I 2025-03-03 17:06:17,515] Trial 17 finished with value: 0.5264270223683496 and parameters: {'alpha_min_ratio': 0.13175453848190546, 'n_alphas': 55}. Best is trial 17 with value: 0.5264270223683496.
# [I 2025-03-03 17:06:28,210] Trial 18 finished with value: 0.510204541974907 and parameters: {'alpha_min_ratio': 0.33015786404490355, 'n_alphas': 40}. Best is trial 17 with value: 0.5264270223683496.
# [I 2025-03-03 17:06:41,194] Trial 19 finished with value: 0.511007563314389 and parameters: {'alpha_min_ratio': 0.20314661472591383, 'n_alphas': 62}. Best is trial 17 with value: 0.5264270223683496.
#    Best params -> {'alpha_min_ratio': 0.13175453848190546, 'n_alphas': 55}
#    Final Model -> Train+Val C-index=0.993, Test C-index=0.607
#    -> 121 features retained
#    Subset Model -> Train+Val C-index=0.993, Test C-index=0.607
# 🔍 Computing SHAP on 121 features...
# ==============================
# 🔹 Subtype: oligodendroglioma
# 🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50
# [I 2025-03-03 17:06:52,149] A new study created in memory with name: no-name-55b29c26-e567-42a5-93ac-3d355f3687d7
#    Baseline C-index -> Train=0.926, Test=0.828
# 🔸 Tuning with Optuna + 5-fold CV...
# [I 2025-03-03 17:07:05,207] Trial 0 finished with value: 0.8488211382113822 and parameters: {'alpha_min_ratio': 0.12021171065841792, 'n_alphas': 73}. Best is trial 0 with value: 0.8488211382113822.
# [I 2025-03-03 17:07:14,704] Trial 1 finished with value: 0.8713211382113821 and parameters: {'alpha_min_ratio': 0.20958936053495086, 'n_alphas': 28}. Best is trial 1 with value: 0.8713211382113821.
# [I 2025-03-03 17:07:23,077] Trial 2 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.41038506427505694, 'n_alphas': 12}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:07:35,498] Trial 3 finished with value: 0.8964430894308943 and parameters: {'alpha_min_ratio': 0.32441659764369557, 'n_alphas': 78}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:07:46,619] Trial 4 finished with value: 0.8838211382113821 and parameters: {'alpha_min_ratio': 0.2331575409781185, 'n_alphas': 50}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:07:57,576] Trial 5 finished with value: 0.9089430894308943 and parameters: {'alpha_min_ratio': 0.3664443441146895, 'n_alphas': 53}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:08:10,037] Trial 6 finished with value: 0.9371544715447154 and parameters: {'alpha_min_ratio': 0.6214460087400331, 'n_alphas': 85}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:08:19,036] Trial 7 finished with value: 0.9322764227642277 and parameters: {'alpha_min_ratio': 0.5644465821101287, 'n_alphas': 24}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:08:31,290] Trial 8 finished with value: 0.9051761517615177 and parameters: {'alpha_min_ratio': 0.8335109128137936, 'n_alphas': 83}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:08:44,581] Trial 9 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5468798943014718, 'n_alphas': 98}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:08:52,858] Trial 10 finished with value: 0.9322764227642277 and parameters: {'alpha_min_ratio': 0.7751991510497944, 'n_alphas': 12}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:09:06,105] Trial 11 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.4345783408365221, 'n_alphas': 97}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:09:15,979] Trial 12 finished with value: 0.9420325203252033 and parameters: {'alpha_min_ratio': 0.6648527273544915, 'n_alphas': 39}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:09:27,084] Trial 13 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.470697667650933, 'n_alphas': 59}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:09:40,367] Trial 14 finished with value: 0.9371544715447154 and parameters: {'alpha_min_ratio': 0.7112173031682425, 'n_alphas': 100}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:09:51,675] Trial 15 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5514012737312732, 'n_alphas': 61}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:09:59,931] Trial 16 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.40260704912727624, 'n_alphas': 10}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:10:09,653] Trial 17 finished with value: 0.8469647696476965 and parameters: {'alpha_min_ratio': 0.8989570221134224, 'n_alphas': 37}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:10:21,363] Trial 18 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5333442404608675, 'n_alphas': 69}. Best is trial 2 with value: 0.9422764227642275.
# [I 2025-03-03 17:10:31,658] Trial 19 finished with value: 0.8864430894308942 and parameters: {'alpha_min_ratio': 0.2773880531680337, 'n_alphas': 42}. Best is trial 2 with value: 0.9422764227642275.
#    Best params -> {'alpha_min_ratio': 0.41038506427505694, 'n_alphas': 12}
#    Final Model -> Train+Val C-index=0.948, Test C-index=0.897
#    -> 15 features retained
#    Subset Model -> Train+Val C-index=0.948, Test C-index=0.897
# 🔍 Computing SHAP on 15 features...
# ✅ Workflow Complete!

# %%
import os
import pickle
import warnings
import numpy as np
import pandas as pd
import shap
import matplotlib.pyplot as plt

from itertools import product
from sklearn.model_selection import train_test_split, KFold
from lifelines.statistics import logrank_test
from lifelines import CoxPHFitter
from sksurv.linear_model import CoxnetSurvivalAnalysis

import optuna

warnings.filterwarnings("ignore")
random_state = 42

results_tracker = {}

def load_data(base_path):
    file_paths = {
        "clinical_data": os.path.join(base_path, "2019_TCGA-CDR-SupplementalTableS1.xlsx"),
        "new_labels": os.path.join(base_path, "Matrix_WHO2021.csv"),
        "gbm_data": os.path.join(base_path, "GBM_450K_Filtered_X-Y,SNPs,Non-overlap850K.csv"),
        "lgg_data": os.path.join(base_path, "LGG-450K_Filtered_X-Y,SNPs,Non-overlap850K.csv"),
    }
    for key, path in file_paths.items():
        if not os.path.exists(path):
            print(f"❌ Error: Missing {key} file: {path}")
            return None

    print("📂 Loading data...")
    main_data_df = pd.read_excel(file_paths["clinical_data"])
    new_categories = pd.read_csv(file_paths["new_labels"])
    gbm_data = pd.read_csv(file_paths["gbm_data"])
    lgg_data = pd.read_csv(file_paths["lgg_data"])
    print("✅ Data Loaded Successfully!")

    results_tracker["data_load"] = {
        "clinical_data": main_data_df.shape,
        "new_labels": new_categories.shape,
        "gbm_data": gbm_data.shape,
        "lgg_data": lgg_data.shape
    }
    return main_data_df, new_categories, gbm_data, lgg_data

def preprocess_methylation_data(df):
    df_trns = df.T
    df_trns.columns = df_trns.iloc[0]
    return df_trns[1:]

def merge_data(main_data_df, new_categories, gbm_data, lgg_data):
    main_data_df.rename(columns={'bcr_patient_barcode': 'Patient_ID'}, inplace=True)
    filtered_data_df = main_data_df[main_data_df['type'].isin(['GBM', 'LGG'])]
    merged_clinical_data = pd.merge(filtered_data_df, new_categories, on='Patient_ID', how='inner')

    gbm_trns_final = preprocess_methylation_data(gbm_data)
    lgg_trns_final = preprocess_methylation_data(lgg_data)
    merged_methylation_data = pd.concat([gbm_trns_final, lgg_trns_final])
    merged_methylation_data.rename(columns={'Index': 'Patient_ID'}, inplace=True)

    final_data = pd.merge(
        merged_methylation_data,
        merged_clinical_data,
        left_index=True,
        right_on='Patient_ID',
        how='inner'
    )
    print(f"✅ Final Merged Data Shape: {final_data.shape}")
    results_tracker["merged_data"] = final_data.shape
    return final_data

def split_data(df):
    df = df[df['classification.2021_simplified.labels'] != 'unclassified']
    subsets = {
        'astrocytoma': df[df['classification.2021_simplified.labels'] == 'astrocytoma'],
        'glioblastoma': df[df['classification.2021_simplified.labels'] == 'glioblastoma'],
        'oligodendroglioma': df[df['classification.2021_simplified.labels'] == 'oligodendroglioma']
    }
    print(f"✅ Data Split into: {', '.join(subsets.keys())}")
    results_tracker["split_data"] = {k: v.shape for k, v in subsets.items()}
    return subsets

def prepare_subtype_data(df):
    df = df.dropna(subset=["OS.time", "OS"])
    df = df.apply(pd.to_numeric, errors="coerce")
    df["OS"] = df["OS"].astype(int)

    methylation_features = [col for col in df.columns if col.startswith("cg")]
    if len(methylation_features) == 0:
        print("❌ No valid methylation features found. Skipping.")
        return None

    X = df[methylation_features]
    y = df[['OS.time', 'OS']]

    X_train_val, X_test, y_train_val, y_test = train_test_split(
        X, y, test_size=0.2, random_state=random_state
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_train_val, y_train_val, test_size=0.25, random_state=random_state
    )
    
    print(f"✅ Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return {
        "X_train": X_train,
        "X_val": X_val,
        "X_test": X_test,
        "y_train": y_train,
        "y_val": y_val,
        "y_test": y_test
    }

def convert_survival_data(y_df):
    return np.array(
        [(bool(event), time) for event, time in zip(y_df["OS"], y_df["OS.time"])],
        dtype=[('event', '?'), ('time', '<f8')]
    )

def train_lasso_cox_model(X_train, y_train_struct, alpha_min_ratio=0.5, n_alphas=50):
    model = CoxnetSurvivalAnalysis(
        l1_ratio=1.0, alpha_min_ratio=alpha_min_ratio, n_alphas=n_alphas
    )
    model.fit(X_train, y_train_struct)
    return model

def extract_significant_features(coxnet, X_train):
    best_alpha_index = np.argmax(np.sum(coxnet.coef_ != 0, axis=0))
    selected_features = X_train.columns[coxnet.coef_[:, best_alpha_index] != 0]
    return selected_features

def evaluate_model(coxnet, X_train, y_train_struct, X_test, y_test_struct):
    train_c_index = coxnet.score(X_train, y_train_struct)
    test_c_index = coxnet.score(X_test, y_test_struct)
    return train_c_index, test_c_index

# ---- Optuna-based CV Tuning ----
from sklearn.model_selection import KFold

def cross_val_c_index(X, y_struct, alpha_min_ratio, n_alphas, n_splits=5):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    c_indexes = []
    for train_idx, val_idx in kf.split(X):
        X_train_fold = X.iloc[train_idx]
        X_val_fold   = X.iloc[val_idx]
        y_train_fold = y_struct[train_idx]
        y_val_fold   = y_struct[val_idx]

        model = CoxnetSurvivalAnalysis(
            l1_ratio=1.0, alpha_min_ratio=alpha_min_ratio, n_alphas=n_alphas
        )
        model.fit(X_train_fold, y_train_fold)
        c_indexes.append(model.score(X_val_fold, y_val_fold))

    return np.mean(c_indexes)

import optuna

def tune_hyperparameters_optuna(X, y_struct, n_trials=20):
    def objective(trial):
        alpha_min_ratio = trial.suggest_float("alpha_min_ratio", 0.3, 0.9)
        n_alphas = trial.suggest_int("n_alphas", 10, 100)
        return cross_val_c_index(X, y_struct, alpha_min_ratio, n_alphas, n_splits=5)

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=n_trials)
    return study.best_params

def compute_shap_importance(model, X_subset):
    print(f"🔍 Computing SHAP on {X_subset.shape[1]} features...")
    explainer = shap.Explainer(model.predict, X_subset)
    shap_values = explainer(X_subset)
    shap.summary_plot(shap_values, X_subset, show=False)
    plt.title("SHAP Summary Plot")
    plt.show()

def main():
    base_path = "/Users/nijat/Downloads/OneDrive_1_2024-09-21/Data"
    data_loaded = load_data(base_path)
    if data_loaded is None:
        return

    main_data_df, new_categories, gbm_data, lgg_data = data_loaded
    merged_data = merge_data(main_data_df, new_categories, gbm_data, lgg_data)
    subsets = split_data(merged_data)

    # -----------
    # Dictionary to store final selected features
    # -----------
    selected_features_dict = {}

    split_data_dict = {}
    for label, df in subsets.items():
        print(f"\n🔹 Processing subtype={label}")
        subtype_data = prepare_subtype_data(df)
        if subtype_data is None:
            continue
        # Convert survival data
        subtype_data["y_train_struct"] = convert_survival_data(subtype_data["y_train"])
        subtype_data["y_val_struct"]   = convert_survival_data(subtype_data["y_val"])
        subtype_data["y_test_struct"]  = convert_survival_data(subtype_data["y_test"])
        split_data_dict[label] = subtype_data

    for label, data in split_data_dict.items():
        print(f"\n==============================")
        print(f"🔹 Subtype: {label}")

        # 1) Baseline
        X_train = data["X_train"]
        X_val   = data["X_val"]
        X_test  = data["X_test"]

        y_train_struct = data["y_train_struct"]
        y_val_struct   = data["y_val_struct"]
        y_test_struct  = data["y_test_struct"]

        print("🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50")
        baseline_model = train_lasso_cox_model(X_train, y_train_struct,
                                               alpha_min_ratio=0.5, n_alphas=50)
        train_c, test_c = evaluate_model(baseline_model, X_train, y_train_struct,
                                         X_test, y_test_struct)
        print(f"   Baseline C-index -> Train={train_c:.3f}, Test={test_c:.3f}")

        # 2) Hyperparam Tuning with Optuna
        print("🔸 Tuning with Optuna + 5-fold CV...")
        best_params = tune_hyperparameters_optuna(X_train, y_train_struct, n_trials=20)
        print(f"   Best params -> {best_params}")

        # 3) Final Model on Train+Val
        X_train_val = pd.concat([X_train, X_val])
        y_train_val = pd.concat([data["y_train"], data["y_val"]])
        y_train_val_struct = convert_survival_data(y_train_val)

        final_model = train_lasso_cox_model(X_train_val, y_train_val_struct,
                                            alpha_min_ratio=best_params["alpha_min_ratio"],
                                            n_alphas=best_params["n_alphas"])
        # Evaluate
        final_train_c, final_test_c = evaluate_model(
            final_model, X_train_val, y_train_val_struct,
            X_test, y_test_struct
        )
        print(f"   Final Model -> Train+Val C-index={final_train_c:.3f}, Test C-index={final_test_c:.3f}")

        # 4) Extract subset
        selected_features = extract_significant_features(final_model, X_train_val)
        print(f"   -> {len(selected_features)} features retained")

        # 5) Retrain only on the subset (to reduce feature count for SHAP)
        final_model_subset = train_lasso_cox_model(
            X_train_val[selected_features],
            y_train_val_struct,
            alpha_min_ratio=best_params["alpha_min_ratio"],
            n_alphas=best_params["n_alphas"]
        )
        subset_train_c, subset_test_c = evaluate_model(
            final_model_subset,
            X_train_val[selected_features],
            y_train_val_struct,
            X_test[selected_features],
            y_test_struct
        )
        print(f"   Subset Model -> Train+Val C-index={subset_train_c:.3f}, Test C-index={subset_test_c:.3f}")

        # 6) SHAP Explanation on final subset model
        compute_shap_importance(final_model_subset, X_train_val[selected_features])

        # 7) Store the selected features in our dictionary
        selected_features_dict[label] = list(selected_features)

    # -----------
    # SAVE SELECTED FEATURES
    # -----------
    save_path = "/Users/nijat/Downloads/selected_features_dict.pkl"
    with open(save_path, "wb") as f:
        pickle.dump(selected_features_dict, f)
    print(f"\n✅ Saved selected feature lists to {save_path}.")

    # Print out a summary
    for label, feats in selected_features_dict.items():
        print(f"{label}: {len(feats)} selected features -> {feats} (first 10)")

    print("\n✅ Workflow Complete!")

if __name__ == "__main__":
    main()
# Out:
# 📂 Loading data...
# ✅ Data Loaded Successfully!
# ✅ Final Merged Data Shape: (653, 403991)
# ✅ Data Split into: astrocytoma, glioblastoma, oligodendroglioma
#
# 🔹 Processing subtype=astrocytoma
# ✅ Train: 153, Val: 51, Test: 52
#
# 🔹 Processing subtype=glioblastoma
# ✅ Train: 116, Val: 39, Test: 39
#
# 🔹 Processing subtype=oligodendroglioma
# ✅ Train: 100, Val: 34, Test: 34
#
# ==============================
# 🔹 Subtype: astrocytoma
# 🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50
# [I 2025-03-03 17:24:20,810] A new study created in memory with name: no-name-3386b56d-0d18-4a59-8138-71b5ec7e0f7e
#    Baseline C-index -> Train=0.851, Test=0.673
# 🔸 Tuning with Optuna + 5-fold CV...
# [I 2025-03-03 17:24:34,678] Trial 0 finished with value: 0.7543476930942685 and parameters: {'alpha_min_ratio': 0.7305728904533094, 'n_alphas': 70}. Best is trial 0 with value: 0.7543476930942685.
# [I 2025-03-03 17:24:48,940] Trial 1 finished with value: 0.7102262169214224 and parameters: {'alpha_min_ratio': 0.4395556667810687, 'n_alphas': 74}. Best is trial 0 with value: 0.7543476930942685.
# [I 2025-03-03 17:24:59,087] Trial 2 finished with value: 0.7271947515029706 and parameters: {'alpha_min_ratio': 0.5308589158226916, 'n_alphas': 25}. Best is trial 0 with value: 0.7543476930942685.
# [I 2025-03-03 17:25:08,865] Trial 3 finished with value: 0.7621678346644101 and parameters: {'alpha_min_ratio': 0.6267506701092418, 'n_alphas': 20}. Best is trial 3 with value: 0.7621678346644101.
# [I 2025-03-03 17:25:18,358] Trial 4 finished with value: 0.7064166931118986 and parameters: {'alpha_min_ratio': 0.43237282706280833, 'n_alphas': 15}. Best is trial 3 with value: 0.7621678346644101.
# [I 2025-03-03 17:25:27,494] Trial 5 finished with value: 0.7541285150120766 and parameters: {'alpha_min_ratio': 0.8115352831784162, 'n_alphas': 12}. Best is trial 3 with value: 0.7621678346644101.
# [I 2025-03-03 17:25:38,258] Trial 6 finished with value: 0.7474946448405352 and parameters: {'alpha_min_ratio': 0.5830008337161103, 'n_alphas': 33}. Best is trial 3 with value: 0.7621678346644101.
# [I 2025-03-03 17:25:52,933] Trial 7 finished with value: 0.7087674670756863 and parameters: {'alpha_min_ratio': 0.3315019616213275, 'n_alphas': 80}. Best is trial 3 with value: 0.7621678346644101.
# [I 2025-03-03 17:26:03,603] Trial 8 finished with value: 0.7142262169214224 and parameters: {'alpha_min_ratio': 0.4930259919678941, 'n_alphas': 32}. Best is trial 3 with value: 0.7621678346644101.
# [I 2025-03-03 17:26:16,583] Trial 9 finished with value: 0.7659320137162603 and parameters: {'alpha_min_ratio': 0.6764634873905915, 'n_alphas': 60}. Best is trial 9 with value: 0.7659320137162603.
# [I 2025-03-03 17:26:32,455] Trial 10 finished with value: 0.7474628356340685 and parameters: {'alpha_min_ratio': 0.8956928606979633, 'n_alphas': 100}. Best is trial 9 with value: 0.7659320137162603.
# [I 2025-03-03 17:26:44,717] Trial 11 finished with value: 0.7639320137162604 and parameters: {'alpha_min_ratio': 0.6828597594694628, 'n_alphas': 50}. Best is trial 9 with value: 0.7659320137162603.
# [I 2025-03-03 17:26:56,653] Trial 12 finished with value: 0.7619320137162603 and parameters: {'alpha_min_ratio': 0.6920727302623323, 'n_alphas': 47}. Best is trial 9 with value: 0.7659320137162603.
# [I 2025-03-03 17:27:09,322] Trial 13 finished with value: 0.7556820137162603 and parameters: {'alpha_min_ratio': 0.7076505997348972, 'n_alphas': 54}. Best is trial 9 with value: 0.7659320137162603.
# [I 2025-03-03 17:27:21,124] Trial 14 finished with value: 0.7560976930942684 and parameters: {'alpha_min_ratio': 0.7811758133909582, 'n_alphas': 45}. Best is trial 9 with value: 0.7659320137162603.
# [I 2025-03-03 17:27:33,989] Trial 15 finished with value: 0.7659773584739338 and parameters: {'alpha_min_ratio': 0.6292535274944424, 'n_alphas': 57}. Best is trial 15 with value: 0.7659773584739338.
# [I 2025-03-03 17:27:47,337] Trial 16 finished with value: 0.7474946448405352 and parameters: {'alpha_min_ratio': 0.5856230643364875, 'n_alphas': 64}. Best is trial 15 with value: 0.7659773584739338.
# [I 2025-03-03 17:28:02,275] Trial 17 finished with value: 0.7602630727596481 and parameters: {'alpha_min_ratio': 0.6260582838799524, 'n_alphas': 87}. Best is trial 15 with value: 0.7659773584739338.
# [I 2025-03-03 17:28:15,568] Trial 18 finished with value: 0.7528682410394738 and parameters: {'alpha_min_ratio': 0.8235362909205055, 'n_alphas': 64}. Best is trial 15 with value: 0.7659773584739338.
# [I 2025-03-03 17:28:26,707] Trial 19 finished with value: 0.7225502635708116 and parameters: {'alpha_min_ratio': 0.5235983909535752, 'n_alphas': 38}. Best is trial 15 with value: 0.7659773584739338.
#    Best params -> {'alpha_min_ratio': 0.6292535274944424, 'n_alphas': 57}
#    Final Model -> Train+Val C-index=0.807, Test C-index=0.715
#    -> 6 features retained
#    Subset Model -> Train+Val C-index=0.807, Test C-index=0.715
# 🔍 Computing SHAP on 6 features...
# ==============================
# 🔹 Subtype: glioblastoma
# 🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50
# [I 2025-03-03 17:28:34,779] A new study created in memory with name: no-name-8e2b9ab9-3da7-4d18-b526-f5ef08bf05df
#    Baseline C-index -> Train=0.844, Test=0.566
# 🔸 Tuning with Optuna + 5-fold CV...
# [I 2025-03-03 17:28:48,390] Trial 0 finished with value: 0.5170939649374034 and parameters: {'alpha_min_ratio': 0.6328791154454769, 'n_alphas': 92}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:28:59,636] Trial 1 finished with value: 0.4906480904030189 and parameters: {'alpha_min_ratio': 0.5044503397426373, 'n_alphas': 49}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:29:10,506] Trial 2 finished with value: 0.4919291797082569 and parameters: {'alpha_min_ratio': 0.549156994659853, 'n_alphas': 46}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:29:19,794] Trial 3 finished with value: 0.49144999628254527 and parameters: {'alpha_min_ratio': 0.4849820628571655, 'n_alphas': 23}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:29:33,648] Trial 4 finished with value: 0.5161038659275025 and parameters: {'alpha_min_ratio': 0.6299031219884561, 'n_alphas': 97}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:29:47,710] Trial 5 finished with value: 0.5107874622167455 and parameters: {'alpha_min_ratio': 0.7415582053789463, 'n_alphas': 88}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:29:57,207] Trial 6 finished with value: 0.48914840115768027 and parameters: {'alpha_min_ratio': 0.5888148777218052, 'n_alphas': 26}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:30:09,080] Trial 7 finished with value: 0.5073051033673678 and parameters: {'alpha_min_ratio': 0.4191826952074953, 'n_alphas': 57}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:30:18,139] Trial 8 finished with value: 0.5076943147022943 and parameters: {'alpha_min_ratio': 0.42012871101511007, 'n_alphas': 17}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:30:30,958] Trial 9 finished with value: 0.5084651743909878 and parameters: {'alpha_min_ratio': 0.7172690651398204, 'n_alphas': 79}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:30:40,863] Trial 10 finished with value: 0.48292492576759083 and parameters: {'alpha_min_ratio': 0.8532477473537246, 'n_alphas': 71}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:30:54,947] Trial 11 finished with value: 0.5054067321244741 and parameters: {'alpha_min_ratio': 0.7042833188521769, 'n_alphas': 100}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:31:09,373] Trial 12 finished with value: 0.512330598744891 and parameters: {'alpha_min_ratio': 0.3155194379561441, 'n_alphas': 95}. Best is trial 0 with value: 0.5170939649374034.
# [I 2025-03-03 17:31:21,956] Trial 13 finished with value: 0.519923706547324 and parameters: {'alpha_min_ratio': 0.6352725115761642, 'n_alphas': 72}. Best is trial 13 with value: 0.519923706547324.
# [I 2025-03-03 17:31:32,561] Trial 14 finished with value: 0.47100586500905595 and parameters: {'alpha_min_ratio': 0.8423310579283727, 'n_alphas': 68}. Best is trial 13 with value: 0.519923706547324.
# [I 2025-03-03 17:31:45,531] Trial 15 finished with value: 0.5180111014966657 and parameters: {'alpha_min_ratio': 0.6518517194198408, 'n_alphas': 80}. Best is trial 13 with value: 0.519923706547324.
# [I 2025-03-03 17:31:57,496] Trial 16 finished with value: 0.46881848481247557 and parameters: {'alpha_min_ratio': 0.7888403813510255, 'n_alphas': 80}. Best is trial 13 with value: 0.519923706547324.
# [I 2025-03-03 17:32:09,471] Trial 17 finished with value: 0.514430037336216 and parameters: {'alpha_min_ratio': 0.6602517537463573, 'n_alphas': 62}. Best is trial 13 with value: 0.519923706547324.
# [I 2025-03-03 17:32:19,694] Trial 18 finished with value: 0.5066277502043462 and parameters: {'alpha_min_ratio': 0.780798935852386, 'n_alphas': 37}. Best is trial 13 with value: 0.519923706547324.
# [I 2025-03-03 17:32:29,651] Trial 19 finished with value: 0.4916023437277275 and parameters: {'alpha_min_ratio': 0.8988009839990491, 'n_alphas': 81}. Best is trial 13 with value: 0.519923706547324.
#    Best params -> {'alpha_min_ratio': 0.6352725115761642, 'n_alphas': 72}
#    Final Model -> Train+Val C-index=0.731, Test C-index=0.523
#    -> 15 features retained
#    Subset Model -> Train+Val C-index=0.731, Test C-index=0.523
# 🔍 Computing SHAP on 15 features...
# ==============================
# 🔹 Subtype: oligodendroglioma
# 🔸 Baseline: alpha_min_ratio=0.5, n_alphas=50
# [I 2025-03-03 17:32:39,615] A new study created in memory with name: no-name-ea155124-2775-4a79-bf14-03739fbe826b
#    Baseline C-index -> Train=0.926, Test=0.828
# 🔸 Tuning with Optuna + 5-fold CV...
# [I 2025-03-03 17:32:47,849] Trial 0 finished with value: 0.9371544715447154 and parameters: {'alpha_min_ratio': 0.6903186096079622, 'n_alphas': 11}. Best is trial 0 with value: 0.9371544715447154.
# [I 2025-03-03 17:33:00,661] Trial 1 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5350260178019749, 'n_alphas': 92}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:33:09,586] Trial 2 finished with value: 0.9371544715447154 and parameters: {'alpha_min_ratio': 0.7069650813970121, 'n_alphas': 25}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:33:21,470] Trial 3 finished with value: 0.9371544715447154 and parameters: {'alpha_min_ratio': 0.7184809753305763, 'n_alphas': 78}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:33:33,881] Trial 4 finished with value: 0.9322764227642277 and parameters: {'alpha_min_ratio': 0.7861450641844155, 'n_alphas': 90}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:33:46,493] Trial 5 finished with value: 0.9371544715447154 and parameters: {'alpha_min_ratio': 0.6955952854602583, 'n_alphas': 90}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:33:55,169] Trial 6 finished with value: 0.9089430894308943 and parameters: {'alpha_min_ratio': 0.34020111449797896, 'n_alphas': 17}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:34:06,166] Trial 7 finished with value: 0.8469647696476965 and parameters: {'alpha_min_ratio': 0.8983338702988994, 'n_alphas': 62}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:34:15,432] Trial 8 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.40864989842915245, 'n_alphas': 29}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:34:27,310] Trial 9 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.4588234652700176, 'n_alphas': 74}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:34:37,331] Trial 10 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5288719644666151, 'n_alphas': 43}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:34:47,246] Trial 11 finished with value: 0.9222764227642276 and parameters: {'alpha_min_ratio': 0.37391870473193384, 'n_alphas': 40}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:34:56,862] Trial 12 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5255864766041864, 'n_alphas': 36}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:35:07,881] Trial 13 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.4488173041627196, 'n_alphas': 57}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:35:20,898] Trial 14 finished with value: 0.9322764227642277 and parameters: {'alpha_min_ratio': 0.6043606502760235, 'n_alphas': 98}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:35:32,890] Trial 15 finished with value: 0.8864430894308942 and parameters: {'alpha_min_ratio': 0.30117025845512796, 'n_alphas': 71}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:35:42,149] Trial 16 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.427174923515426, 'n_alphas': 29}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:35:52,325] Trial 17 finished with value: 0.9322764227642277 and parameters: {'alpha_min_ratio': 0.5745009383982149, 'n_alphas': 45}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:36:02,846] Trial 18 finished with value: 0.9322764227642277 and parameters: {'alpha_min_ratio': 0.6143990883405669, 'n_alphas': 51}. Best is trial 1 with value: 0.9422764227642275.
# [I 2025-03-03 17:36:14,041] Trial 19 finished with value: 0.9422764227642275 and parameters: {'alpha_min_ratio': 0.5054216348402112, 'n_alphas': 62}. Best is trial 1 with value: 0.9422764227642275.
#    Best params -> {'alpha_min_ratio': 0.5350260178019749, 'n_alphas': 92}
#    Final Model -> Train+Val C-index=0.927, Test C-index=0.897
#    -> 9 features retained
#    Subset Model -> Train+Val C-index=0.927, Test C-index=0.897
# 🔍 Computing SHAP on 9 features...
# ✅ Saved selected feature lists to /Users/nijat/Downloads/selected_features_dict.pkl.
# astrocytoma: 6 selected features -> ['cg06325209', 'cg16421411', 'cg13421612', 'cg17754510', 'cg13045134', 'cg17861863'] (first 10)
# glioblastoma: 15 selected features -> ['cg01434649', 'cg03130910', 'cg04798314', 'cg14701108', 'cg13686615', 'cg13074295', 'cg06224587', 'cg24869601', 'cg16871519', 'cg12882103', 'cg01414268', 'cg08461107', 'cg00157359', 'cg23386212', 'cg07150062'] (first 10)
# oligodendroglioma: 9 selected features -> ['cg05270572', 'cg20541238', 'cg11410023', 'cg20866694', 'cg07302069', 'cg15173134', 'cg27086773', 'cg17935217', 'cg03690837'] (first 10)
#
# ✅ Workflow Complete!
